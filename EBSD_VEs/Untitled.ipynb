# %%
import numpy as np

# %%
const_indicies = np.arange(0, 2, 1).astype(int)
phase_labels = ["Ti_alpha", "Ti_beta"]
volume_element = {'constituent_material_idx' : const_indicies,
                  'constituent_phase_label' : phase_labels}

print(volume_element)
# Out:
# {'constituent_material_idx': array([0, 1]), 'constituent_phase_label': ['Ti_alpha', 'Ti_beta']}

# %%
new_volume_element = volume_element.copy
const_indicies = np.arange(0, 8, 1).astype(int)

# %%
phases = np.array([
                  [[1, 0],
                  [1, 1]],
                  [[0, 1],
                  [0, 0]],
                  ])
print(phases)
phase_labels = np.where(phases == 1, "Ti_alpha", "Ti_beta").reshape(-1)
print(phase_labels)
# Out:
# [[[1 0]
#   [1 1]]
#
#  [[0 1]
#   [0 0]]]
# ['Ti_alpha' 'Ti_beta' 'Ti_alpha' 'Ti_alpha' 'Ti_beta' 'Ti_alpha' 'Ti_beta'
#  'Ti_beta']
